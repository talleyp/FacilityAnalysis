# %%
## Cost to materials, and normalized by weight
# [$/lb]
m = -0.07 # manual demanufacturing 
s = -0.04 # shredding 
f = -0.03 # metal finder 

## Price to sell for TV's
# price per pound multiplied by percentage of TV unit is
steel = 0.06 * 0.0299 
boards2 = 0.35 * 0.0699
wire = 0.46 * 0.0099
plastic = 0.07 * 0.0599
cones = 0.42 * 0.0249
dwire = 0.65 * 0.0099
pcopper = 0.08 * 0.0240
palum = 0.45 * 0.0019
tube = 0.06 * 0.1499
leadglass = -0.13 * 0.62
processing_cost = sum([steel boards2 wire plastic cones dwire pcopper palum tube leadglass])
# Out:
# -0.016932000000000003

# %%
function holding_cost(x,y) 
    holding_factor = 1 # Place holder for holding cost [$/(gaylord of space)]
    return -1*holding_factor*(div(x,y)+1) # where x is pounds of material, and y is [lbs/gaylord]
end
function shipping_cost(x,y)
    shipping_factor = 1 # place holder for shipping cost [$/(gaylord sent)]
    return -1*shipping_factor*(div(x,y)+1)# where x is pounds of material, and y is [lbs/gaylord]
end
# Out:
# shipping_cost (generic function with 1 method)

# %%
function pre_process_cost(x,t)
    ## Cost to materials, and normalized by weight
    # [$/lb]
    m = -0.07 # manual demanufacturing 
    s = -0.04 # shredding 
    f = -0.03 # metal finder 

    ## Price to sell for TV's
    # price per pound multiplied by percentage of TV unit is
    steel = 0.06 * 0.0299 
    boards2 = 0.35 * 0.0699
    wire = 0.46 * 0.0099
    plastic = 0.07 * 0.0599
    cones = 0.42 * 0.0249
    dwire = 0.65 * 0.0099
    pcopper = 0.08 * 0.0240
    palum = 0.45 * 0.0019
    tube = 0.06 * 0.1499
    leadglass = -0.13 * 0.62
    selling_price = sum([steel boards2 wire plastic cones dwire pcopper palum tube leadglass])
    
    return  x*(1+m+s+f+selling_price) + t*holding_cost(x,450) + shipping_cost(x,10000)
end
# Out:
# pre_process_cost (generic function with 1 method)

# %%
function post_process_cost(x, proccess_t, t)
    orig_weight = x/0.62
    accum_cost = pre_process_cost(orig_weight, proccess_t)
    
    return 0.10*x + t*holding_cost(x,450) + shipping_cost(x,10000)
end
# Out:
# post_process_cost (generic function with 1 method)

# %%
n = 1000
pre_cost = zeros(n,n)
weight_spread = linspace(400,20000,n)
time = linspace(1,n,n)

for i=1:n
    for j=1:n
        pre_cost[i,j] = pre_process_cost(weight_spread[i], time[j])
    end
end

# %%
using Plots

# %%
plot(weight_spread, time, pre_cost,st=:surface,xlab = "weight", ylab = "time", zlab = "Profit")
# Out:
# <img src="data:image/png;base64,..." />

# %%
savefig("profit_surface.png")

# %% [markdown]
# Plot level curve to see where profit hits 0

# %%
plot(time, vec(pre_cost[4,:]),xlab = "time", ylab = "Profit", label="1 gaylord")
plot!(time, vec(pre_cost[200,:]),label="10 gaylords")
plot!(time, vec(pre_cost[1000,:]),label="45 gaylords")
title!("Profit level curves")
scatter!([385],[0], label="t=385")
# Out:
# <img src="data:image/png;base64,..." />

# %%
savefig("profit_level_curves.png")

# %%
using GLM, RDatasets

# %%
data = DataFrame(X=time, Y=vec(pre_cost[4,:]));

# %%
lm1 = fit(LinearModel, Y ~ X, data)
# Out:
# DataFrames.DataFrameRegressionModel{GLM.LinearModel{GLM.LmResp{Array{Float64,1}},GLM.DensePredQR{Float64}},Array{Float64,2}}
#
# Formula: Y ~ 1 + X
#
# Coefficients:
#              Estimate   Std.Error     t value Pr(>|t|)
# (Intercept)   385.849 2.62888e-14  1.46773e16   <1e-99
# X                -2.0 4.54995e-17 -4.39566e16   <1e-99
